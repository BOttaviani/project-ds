# %% [markdown]
# ## Import des librairies

# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.streaming import StreamingContext
from pyspark.sql.functions import from_json
from pyspark.sql import Row
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.types import *
from pyspark.ml.feature import HashingTF,Tokenizer,StopWordsRemover
from pyspark.mllib.linalg import Vectors, SparseVector
from pyspark.mllib.util import MLUtils
from  pyspark.mllib.classification import SVMModel, SVMWithSGD
from pymongo import MongoClient
import pprint as p
import pandas, json, sys
import treetaggerwrapper
tagger = treetaggerwrapper.TreeTagger(TAGLANG='fr')

from whatthelang import WhatTheLang
wtl = WhatTheLang()

# Création d'un spark context, d'un sql context et d'un streaming context
sc = SparkContext("local[2]","Commentaires AirBnB")
sc.setLogLevel("FATAL")
sqlContext = SQLContext(sc)
ssc = StreamingContext(sc, 1)
socket_stream = ssc.socketTextStream("localhost",9999)

stopwords = sc.textFile("Data/French_stop_words").collect()

def comment_to_lemme(comment):
    t=treetaggerwrapper.make_tags(tagger.tag_text(comment))
    lemme=''
    for i in t:
        if type(i)==treetaggerwrapper.Tag:
            if i.pos[:3] in ('ADJ', 'ADV', 'INT','KON','NOM','VER'): 
                if i.lemma !='dns-remplacé':
                    if len(i.lemma)>1 :
                        lemme =lemme+' '+i.lemma.split('|')[0].lower()
    return lemme

# %% [markdown]
# ## Réception des données, transformation, prédiction et enregistrement sur MongoDB

# %%
# Récupération sur une fenêtre d'1s
flux = socket_stream.window( 1 )

## Chargement du modèle calculé
SVMModel = SVMModel.load(sc, "modele/SVM_HTF")

# Traitement sur chaque ligne du commentaire

def TraitementCommentaire(x):
 # Récupération des RDD dans une liste
    x = x.collect()

 # Gestion de la fin du fichier
    if (x == 'Fini'):
        # arrêt des context
        global ssc
        global sqlContext
        global sc
        ssc.stop()
        sqlContext.stop()
        sc.stop()
        print("Le traitement du flux est terminé")
        return 1
            
    # Connection à la base MongoDB (qui tourne sur Docker)
    client = MongoClient('localhost:27017')
    db=client.test.Comments 
    

    # Gestion des différents item de la liste
    for item in x:
        comment_texte = item
        #print(comment_texte)
        
        #transformation en dataframe pandas
        comment = pandas.read_json(comment_texte,typ='series').to_frame().transpose()
        comment['comments']=comment['comments'].replace("\r\n", "")
        comment['comments']=comment['comments'].replace("\n", "")
        comment['comments']=comment['comments'].astype(str)
        # Détection de la langue et ajout au dataframe
        comment['langage']=comment['comments'].apply(wtl.pred_prob)
        comment['langue']=comment['langage'].str[0].str[0].str[0]
        comment['lg_proba']=comment['langage'].str[0].str[0].str[1]
        #print(comment)
        comment=comment.drop(['langage'],axis=1)
        comment = comment[(comment['lg_proba']>0.8) & (comment['langue']=='fr')]
        comment['comments'] = comment['comments'].apply(lambda x: x.replace('.',' ').replace('@',' ').replace('+',' ').
            replace(',',' ').replace(';',' ').replace('!',' ').replace('  ',' '))

        comment['comment_lemm'] = comment['comments'].apply(comment_to_lemme)
        #print(comment)
        #print(comment.shape[0])
        test_langue = comment.shape[0]
        if (test_langue > 0) :
            #print("test OK")
            #transformation du dataframe Pandas en RDD
            CommentDF = sqlContext.createDataFrame(comment[['id','comment_lemm']])
            CommentDF.registerTempTable("CommentDF")
            
            tokenizer = Tokenizer(inputCol="comment_lemm", outputCol="words")
            wordsData = tokenizer.transform(CommentDF)
            remover = StopWordsRemover(stopWords=stopwords, inputCol="words",outputCol="removed")
            wordsData_SW = remover.transform(wordsData)
            hashingTF = HashingTF(inputCol="removed", outputCol="features", numFeatures=12000)
            hashingTF_model = hashingTF.transform(wordsData_SW)
            hashingTF_transfo = MLUtils.convertVectorColumnsFromML(hashingTF_model, "features")
            
            #Vecteur_Apredire=hashingTF_transfo.select("features").take(1)
            #Vecteur_Apredire.show(n=1)
            #P=Vecteur_Apredire[0].features
            
            #P=SparseVector(20000, {4543: 1.0, 5284: 1.0, 8353: 1.0, 8809: 1.0, 10935: 1.0, 10983: 1.0})

            #prediction_GBT = GBTModel.predict(hashingTF_transfo.rdd.map(lambda x: x.features))
            prediction_SVM = SVMModel.predict(hashingTF_transfo.rdd.map(lambda x: x.features))
            prediction=prediction_SVM.take(1)

            comment['Prediction']=prediction[0]
        
            print("Insertion")
            
            # insertion dans MongoDB si Français ou Anglais avec une probabilité à plus de 80%
            db.insert_many(comment[(comment['lg_proba']>0.8) & (comment['langue']=='fr')].to_dict('records'))
    
            return 0
    # Fermeture du client MongoDB
    client.close()

    return 0
# Traitement de tous les RDD reçus dans le streaming en appliquant la fonction précédente
flux.foreachRDD(TraitementCommentaire)

# démarrage du flux
ssc.start()
# Out:
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion
# Insertion

# %% [markdown]
# ## Arrêt du streaming avant la fin du traitement du flux

# %%
ssc.stop()
sc.stop()

# %% [markdown]
# ## Test des données présentes en base

# %%
# connection à la base MongoDB
client = MongoClient('localhost:27017')
db=client.test.Comments 


# récupération des données de la collection
data = db.find({"Prediction":0})
nb = data.count()
# display the data
print(nb)
for i in data:
    p.pprint(i)
# Out:
# 11
# {'Prediction': 0,
#  '_id': ObjectId('5b6c278db726e8300221f336'),
#  'comment_lemm': ' petit nid fouiller douillet situer appartement tranversant '
#                  'très lumineux fenêtre piece situer étage ascenseur même bon '
#                  'journée marche ne avoir pas paraître pénaliser mais '
#                  'contraire entrée appartement beau décoration très '
#                  'confortable bien équiper lire 160cm digne nom bouillir faire '
#                  'oublier marché monter vrai airbnb confier lieu vie confiance '
#                  'hôte avoir être très réactif et avoir faciliter séjour point '
#                  'demander revenir être si occasion présenter merci encore',
#  'comments': 'Un petit nid fouiller douillet situé dans appartement '
#              'tranversant très lumineux avec une fenêtre dans chaque piece '
#              'Situé au 4ème étage sans ascenseur même après une bonne journée '
#              'de marche ne nous a pas paru pénalisant Mais au contraire dès '
#              "l'entrée dans l'appartement  une belle décoration très "
#              'confortable bien équipé un VRAI lit en 160cm digne de se nom '
#              'vous bous fera oublié les marchés montées  un vrai airbnb où '
#              'Anne nous confie son lieux de vie en toute confiance \n'
#              'Notre hôtes a été très réactive et nous a facilité notre séjour '
#              'pour tous les points demandés \n'
#              "Nous reviendrons chez Anne c'est sur si l'occasion se présente à "
#              'nous \n'
#              ' Merci encore ',
#  'date': 1509667200000,
#  'id': 208779822,
#  'langue': 'fr',
#  'lg_proba': 0.9922103581022618,
#  'listing_id': 3109,
#  'reviewer_id': 4142888,
#  'reviewer_name': 'Patricia'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c27bab726e8300221f366'),
#  'comment_lemm': ' simplement fantastique même arriver jean marier faciliter '
#                  'séjour explication précis rejoindre pont et foi place verre '
#                  'pont supérieur vue magnifique et vie bord pouvoir commencer '
#                  'un weekend famille ou ami foncer œil fermé',
#  'comments': 'Simplement fantastique \n'
#              'Avant même l arrivée jean marie nous facilite le séjour des '
#              'explications précises pour rejoindre le pont \n'
#              'Et une fois sur place un verre sur le pont supérieur avec une '
#              'vue magnifique sur la Tour Eiffel et la vie à bord peut '
#              'commencer \n'
#              'Un weekend en famille ou entre amis à Paris ? Foncez les yeux '
#              'fermés ',
#  'date': 1496707200000,
#  'id': 158343256,
#  'langue': 'fr',
#  'lg_proba': 0.8472969868884476,
#  'listing_id': 9342,
#  'reviewer_id': 35962847,
#  'reviewer_name': 'Julien'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c27dbb726e8300221f37d'),
#  'comment_lemm': ' logement atypique emplacement idéal malheureusement n’avons '
#                  'pas pouvoir profiter terrasse',
#  'comments': 'Logement atypique dans un emplacement idéal \n'
#              'Malheureusement nous n’avons pas pu profiter de la terrasse',
#  'date': 1520553600000,
#  'id': 241489788,
#  'langue': 'fr',
#  'lg_proba': 0.9500790823577394,
#  'listing_id': 9342,
#  'reviewer_id': 104741884,
#  'reviewer_name': 'Pascal'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c2809b726e8300221f39a'),
#  'comment_lemm': ' appartement être impeccable il être même très sympa être '
#                  'venir travail et ne avoir trop pouvoir visiter mais quartier '
#                  'air assez animer même si appartement être calme recommander',
#  'comments': "L'appartement de Pascal est impeccable Il est lui même très "
#              "sympa Nous étions venu pour le travail et nous n'avons trop pu "
#              "visiter mais le quartier à l'air assez animé même si "
#              "l'appartement lui est au calme Je recommande ",
#  'date': 1513123200000,
#  'id': 218513031,
#  'langue': 'fr',
#  'lg_proba': 0.9844435452361164,
#  'listing_id': 10010,
#  'reviewer_id': 67021872,
#  'reviewer_name': 'Anne-Sophie'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c2829b726e8300221f3af'),
#  'comment_lemm': " véritable nid bon gout et confort détail petit déjeuner j' "
#                  'avoir passer très peu temps mais revenir ou comment trouver '
#                  'endroit calme absolu coter chambrer alors que être mètre un '
#                  'quartier plus chaud et sympa moment capitale',
#  'comments': 'Un véritable nid de bon gout et de confort jusque dans les '
#              "détails du petite déjeuner  J'y ai passé très peu de temps mais "
#              "j'y reviendrai \n"
#              "Ou comment trouver une endroit d'un calme absolu coté chambre "
#              "alors que vous êtes à 100 mètres d'un des quartier les plus "
#              'chauds (et sympa selon moi) du moment dans la capitale ',
#  'date': 1503187200000,
#  'id': 184805759,
#  'langue': 'fr',
#  'lg_proba': 0.9844549433885695,
#  'listing_id': 10270,
#  'reviewer_id': 21414659,
#  'reviewer_name': 'Loïc'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c287eb726e8300221f3d5'),
#  'comment_lemm': ' appartement fonctionnel bien placer petit rue fleuri et '
#                  'calme proche transport commun et commerce être très agréable '
#                  'd’avoir nécessaire petit déjeuner être très accueillant '
#                  'l’écoute et disponible bémol voisin parfois bruyant nuit '
#                  'mais c’est',
#  'comments': 'Appartement fonctionnel bien placé dans une petite rue fleurie '
#              'et calme  proche des transports en commun et des commerces  Il '
#              'est très agréable d’avoir tout le nécessaire pour le petit '
#              'déjeuner \n'
#              'Pascal est très accueillant à l’écoute et disponible \n'
#              'Petit bémol un voisin parfois bruyant la nuit   mais c’est '
#              'Paris ',
#  'date': 1526083200000,
#  'id': 263466700,
#  'langue': 'fr',
#  'lg_proba': 0.9922065583423111,
#  'listing_id': 10270,
#  'reviewer_id': 13225860,
#  'reviewer_name': 'Richard'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c2890b726e8300221f3dc'),
#  'comment_lemm': ' ne peur rêver logement mieux situer avoir aussi apprécier '
#                  'dossier très clair et très complet que avoir faire parvenir',
#  'comments': 'On ne peur rêver un logement mieux situé Nous avons aussi '
#              'apprécié le dossier très clair et très complet que Léna nous a '
#              'fait parvenir ',
#  'date': 1497744000000,
#  'id': 161660554,
#  'langue': 'fr',
#  'lg_proba': 0.98639284741291,
#  'listing_id': 11170,
#  'reviewer_id': 64205617,
#  'reviewer_name': 'Jean-Louis'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c28a8b726e8300221f3f9'),
#  'comment_lemm': ' mais avoir être très disponible logement être soigner et '
#                  'literie confortable recommander',
#  'comments': 'Mais tu as été très disponible Le logement est soigné et la '
#              'literie confortable Je recommande ',
#  'date': 1499299200000,
#  'id': 167264108,
#  'langue': 'fr',
#  'lg_proba': 0.9482049801316239,
#  'listing_id': 11213,
#  'reviewer_id': 16148997,
#  'reviewer_name': 'Arthur'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c28eab726e8300221f414'),
#  'comment_lemm': ' bon rapport qualité prix',
#  'comments': 'Bon rapport qualité/prix',
#  'date': 1523145600000,
#  'id': 251482335,
#  'langue': 'fr',
#  'lg_proba': 0.9863700486225223,
#  'listing_id': 11213,
#  'reviewer_id': 76294624,
#  'reviewer_name': 'Isabelle'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c2902b726e8300221f421'),
#  'comment_lemm': ' retour jour et encore charme et notamment appartement '
#                  'quartier ambiance proximité description appartement être '
#                  'tout fait conforme propre équipement dernier cri qualité et '
#                  'mobilier luxueux arrivé avoir être accueillir avoir prendre '
#                  'soin tout expliquer par suite avoir communiquer propriétaire '
#                  'rassurer que aller bien et avoir rapidement répondre avoir '
#                  'cuisiner beaucoup et proximité boulangerie épicerie marchand '
#                  'vin boutique pas métro soit et falloir que savoir que métro '
#                  'être plus profond atteindre escalier colimaçon ou ascenseur '
#                  'mais être réparation avoir apprendre hasard ami petit '
#                  'mention avoir être apprécier et aussi que promener falloir '
#                  'attendre monter et descendre rue ou escalier mais si vouloir '
#                  'vivre et proximité gens être parfait',
#  'comments': 'De retour depuis 2 jours et encore sous le charme de Paris et '
#              "notamment Montmartre L'appartement le quartier l'ambiance la "
#              "proximité de tout La description de l'appartement était tout à "
#              'fait conforme propre avec tous les équipements derniers cris de '
#              'qualité et mobiliers luxueux À notre arrivée nous avons été '
#              'accueillis par Magali qui a pris soin de tout nous expliquer Par '
#              'la suite nous avons communiqué avec Sylvie la propriétaire pour '
#              'la rassurer que tout allait bien et elle nous a rapidement '
#              'répondu Nous avons cuisiné beaucoup et à proximité de plusieurs '
#              'boulangeries épiceries marchands de vins boutiques à 2 pas du '
#              'Sacré-Coeur de 3 métros soit Pigalle Anvers et Abesses Par '
#              'contre il faut que vous sachiez que le métro Abesses est un des '
#              "plus profonds de Paris que vous atteignez par l'escalier en "
#              "colimaçon ou l'ascenseur mais elle était en réparation ce que "
#              'nous avons appris par hasard par un ami chez nous à Montréal '
#              'Peut-être une petite mention aurait été appréciée et aussi que '
#              "pour se promener dans Montmartre il faut s'attendre à monter et "
#              'descendre plusieurs rues ou escaliers Mais si vous voulez vivre '
#              "Paris et la proximité des gens c'est parfait ",
#  'date': 1506729600000,
#  'id': 198629749,
#  'langue': 'fr',
#  'lg_proba': 0.9883307509178587,
#  'listing_id': 11265,
#  'reviewer_id': 143623836,
#  'reviewer_name': 'Danielle'}
# {'Prediction': 0,
#  '_id': ObjectId('5b6c291fb726e8300221f42d'),
#  'comment_lemm': ' appartement être vrai refuge pari près métro ligne rapide '
#                  'et décervant centre idéal sorti théatre',
#  'comments': 'l appartement est un vrai refuge dans paris près du métro ligne '
#              '14 rapide et décervant le centre idéal pour les sorties théatre',
#  'date': 1522540800000,
#  'id': 248746645,
#  'langue': 'fr',
#  'lg_proba': 0.9922065583423111,
#  'listing_id': 11798,
#  'reviewer_id': 27055245,
#  'reviewer_name': 'Sabine'}

# %% [markdown]
# Adapté des scripts du projet GitHub suivant : Stream-Processing-using-PySpark-and-MongoDB--master
#
# https://github.com/vipulkrishnanmd/Stream-Processing-using-PySpark-and-MongoDB-
