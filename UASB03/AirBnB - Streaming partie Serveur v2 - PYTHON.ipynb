# %% [markdown]
# ## Import des librairies et chargement du fichier

# %%
import socket
import time
from random import randint
# Temps d'attente maximale
ATTENTE_MAX = 1

fichier = open('Data/comment_2018.json', 'rb')
lignes = fichier.readlines()

# %% [markdown]
# ## Transfert des données

# %%
# création du socket
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# choix du serveur et du port
s.bind(('localhost', 9999))
# Ecoute des connections
s.listen(1)

while True:
    print('\nAttente d\'une connection')
    conn, addr = s.accept()
    
    print('\nConnection par', addr)
    
    try:
        print('\nEnvoi des données...\n')
        i = 1
        while(i < len(lignes)):
            conn.send(lignes[i].decode("utf8").encode('utf8'))
            i = i + 1
            attente = randint(0, ATTENTE_MAX)
            print ("Attente " + str(attente) + " secondes ")
            time.sleep( attente)
        # Envoi du signal de fin
        conn.send(b'Fini\r\n')
        break
    except Exception as ex:
        print (ex)

print("Streaming terminé avec succès")
conn.close()
s.close()
# Out:
# Attente d'une connection
#
# Connection par ('127.0.0.1', 50784)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 51348)
#
# Envoi des données...
#
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 52362)
#
# Envoi des données...
#
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 52608)
#
# Envoi des données...
#
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 53236)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 53508)
#
# Envoi des données...
#
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 53908)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 54304)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 56848)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 57154)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 57420)
#
# Envoi des données...
#
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection
#
# Connection par ('127.0.0.1', 57740)
#
# Envoi des données...
#
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 0 secondes
# Attente 1 secondes
# Attente 1 secondes
# Attente 1 secondes
# [Errno 32] Broken pipe
#
# Attente d'une connection

# %% [markdown]
# ## Arrêt du streaming  (après interruption du Kernel Jupyter)

# %%
conn.close()
s.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-52c057e37a39> in <module>()
# ----> 1 conn.close()
#       2 s.close()
#
# NameError: name 'conn' is not defined

# %% [markdown]
# Adapté des scripts du projet GitHub suivant : Stream-Processing-using-PySpark-and-MongoDB--master
#
# https://github.com/vipulkrishnanmd/Stream-Processing-using-PySpark-and-MongoDB-
