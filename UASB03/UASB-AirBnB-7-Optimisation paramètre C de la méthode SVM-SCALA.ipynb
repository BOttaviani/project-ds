// %% [markdown]
// # CNAM UASB03 - CERTIFICATION ANALYSE DE DONNEES MASSIVES
// ## Projet d'analyse de sentiment sur les commentaires Airbnb en français
//
// ***
// Notebook Scala de recherche de la valeur optimale pour le paramètre de régularisation C du modèle SVM.
//
// Cette recherche est réalisée sur les 4 vectorisations des commentaires

// %% [markdown]
// -  ## Variation du paramètre C pour SVM avec vectorisation HTF

// %%
//CONTEXTE DE TRAVAIL
import org.apache.spark.rdd.RDD
import org.apache.spark.mllib.regression.LabeledPoint
import org.apache.spark.mllib.util.MLUtils
import org.apache.spark.mllib.classification.{SVMModel, SVMWithSGD}
import org.apache.spark.mllib.optimization.L1Updater
import org.apache.spark.mllib.evaluation.BinaryClassificationMetrics

//LECTURE D'UN FICHIER AU FORMAT LIBSVM
val echantillon_LIBSVM: RDD[LabeledPoint] = MLUtils.loadLibSVMFile(sc, "Data/Vecto_HTF_V6")

//PARTAGE DE L'ECHANTILLON EN JEUX D'APPRENTISSAGE ET DE VALIDATION
val splits = echantillon_LIBSVM.randomSplit(Array(0.7, 0.3))
val (trainingData, validationData) = (splits(0), splits(1))

//APPLICATION DU MODELE AU JEU D'APPRENTISSAGE
val numIterations = 100
val modele_sansC = SVMWithSGD.train(trainingData, numIterations)

//EVALUATION DU MODELE AVEC VALEUR C PAR DEFAUT
modele_sansC.clearThreshold()
// APPLICATION DU MODELE AU JEU DE VALIDATION
val scoreAndLabels_sansC = validationData.map { point =>
  val score = modele_sansC.predict(point.features)
  (score, point.label)
}
// CALCUL DE L'AIRE ROC
val metrics_sansC = new BinaryClassificationMetrics(scoreAndLabels_sansC)
val auROC_sansC = metrics_sansC.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0
val C1 = 0.0
val svmAlgC1 = new SVMWithSGD()
svmAlgC1.optimizer
  .setNumIterations(100)
  .setRegParam(C1)
  .setUpdater(new L1Updater)
val modele_avecC1 = svmAlgC1.run(trainingData)

modele_avecC1.clearThreshold()
val scoreAndLabels_avecC1 = validationData.map { point =>
  val score = modele_avecC1.predict(point.features)
  (score, point.label)
}
val metrics_avecC1 = new BinaryClassificationMetrics(scoreAndLabels_avecC1)
val auROC_avecC1 = metrics_avecC1.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0.00001
val C2 = 0.00001
val svmAlgC2 = new SVMWithSGD()
svmAlgC2.optimizer
  .setNumIterations(100)
  .setRegParam(C2)
  .setUpdater(new L1Updater)
val modele_avecC2 = svmAlgC2.run(trainingData)

modele_avecC2.clearThreshold()
val scoreAndLabels_avecC2 = validationData.map { point =>
  val score = modele_avecC2.predict(point.features)
  (score, point.label)
}
val metrics_avecC2 = new BinaryClassificationMetrics(scoreAndLabels_avecC2)
val auROC_avecC2 = metrics_avecC2.areaUnderROC()
 
//EVALUATION DU MODELE AVEC VALEUR C =0.0001
val C3 = 0.0001
val svmAlgC3 = new SVMWithSGD()
svmAlgC3.optimizer
  .setNumIterations(100)
  .setRegParam(C3)
  .setUpdater(new L1Updater)
val modele_avecC3 = svmAlgC3.run(trainingData)

modele_avecC3.clearThreshold()
val scoreAndLabels_avecC3 = validationData.map { point =>
  val score = modele_avecC3.predict(point.features)
  (score, point.label)
}
val metrics_avecC3 = new BinaryClassificationMetrics(scoreAndLabels_avecC3)
val auROC_avecC3 = metrics_avecC3.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0.001
val C4 = 0.001
val svmAlgC4 = new SVMWithSGD()
svmAlgC4.optimizer
  .setNumIterations(100)
  .setRegParam(C4)
  .setUpdater(new L1Updater)
val modele_avecC4 = svmAlgC4.run(trainingData)
modele_avecC4.clearThreshold()

val scoreAndLabels_avecC4 = validationData.map { point =>
  val score = modele_avecC4.predict(point.features)
  (score, point.label)
}
val metrics_avecC4 = new BinaryClassificationMetrics(scoreAndLabels_avecC4)
val auROC_avecC4 = metrics_avecC4.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0.01
val C5 = 0.01
val svmAlgC5 = new SVMWithSGD()
svmAlgC5.optimizer
  .setNumIterations(100)
  .setRegParam(C5)
  .setUpdater(new L1Updater)
val modele_avecC5 = svmAlgC5.run(trainingData)
modele_avecC5.clearThreshold()
val scoreAndLabels_avecC5 = validationData.map { point =>
  val score = modele_avecC5.predict(point.features)
  (score, point.label)
}
val metrics_avecC5 = new BinaryClassificationMetrics(scoreAndLabels_avecC5)
val auROC_avecC5 = metrics_avecC5.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0.1
val C6 = 0.1
val svmAlgC6 = new SVMWithSGD()
svmAlgC6.optimizer
  .setNumIterations(100)
  .setRegParam(C6)
  .setUpdater(new L1Updater)
val modele_avecC6 = svmAlgC6.run(trainingData)
modele_avecC6.clearThreshold()
val scoreAndLabels_avecC6 = validationData.map { point =>
  val score = modele_avecC6.predict(point.features)
  (score, point.label)
}
val metrics_avecC6 = new BinaryClassificationMetrics(scoreAndLabels_avecC6)
val auROC_avecC6 = metrics_avecC6.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C =0.5
val C7 = 0.5
val svmAlgC7 = new SVMWithSGD()
svmAlgC7.optimizer
  .setNumIterations(100)
  .setRegParam(C7)
  .setUpdater(new L1Updater)
val modele_avecC7 = svmAlgC7.run(trainingData)
modele_avecC7.clearThreshold()
val scoreAndLabels_avecC7 = validationData.map { point =>
  val score = modele_avecC7.predict(point.features)
  (score, point.label)
}
val metrics_avecC7 = new BinaryClassificationMetrics(scoreAndLabels_avecC7)
val auROC_avecC7 = metrics_avecC7.areaUnderROC()
// Out:
// echantillon_LIBSVM = MapPartitionsRDD[13473] at map at MLUtils.scala:84
// splits = Array(MapPartitionsRDD[13474] at randomSplit at <console>:101, MapPartitionsRDD[13475] at randomSplit at <console>:101)
// trainingData = MapPartitionsRDD[13474] at random...
// MapPartitionsRDD[13474] at randomSplit at <console>:101

// %%
println("Vectorisation avec HashingTF")
println("==========================================================")
println(s"Area under ROC pour methode sans Regparam = $auROC_sansC")
println(s"paramètre de régularisation : C = $C1")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC1")
println(s"paramètre de régularisation : C = $C2")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC2")
println(s"paramètre de régularisation : C = $C3")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC3")
println(s"paramètre de régularisation : C = $C4")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC4")
println(s"paramètre de régularisation : C = $C5")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC5")
println(s"paramètre de régularisation : C = $C6")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC6")
println(s"paramètre de régularisation : C = $C7")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC7")
// Out:
// Vectorisation avec HashingTF
// ==========================================================
// Area under ROC pour methode sans Regparam = 0.9696303138980918
// paramètre de régularisation : C = 0.0
// Area under ROC pour methode avec Regparam = 0.9708127298085405
// paramètre de régularisation : C = 1.0E-5
// Area under ROC pour methode avec Regparam = 0.9707801264286567
// paramètre de régularisation : C = 1.0E-4
// Area under ROC pour methode avec Regparam = 0.9704736546577495
// paramètre de régularisation : C = 0.001
// Area under ROC pour methode avec Regparam = 0.9669771232951121
// paramètre de régularisation : C = 0.01
// Area under ROC pour methode avec Regparam = 0.9228459128040646
// paramètre de régularisation : C = 0.1
// Area under ROC pour methode avec Regparam = 0.6444431161585974
// paramètre de régularisation : C = 0.5
// Area under ROC pour methode avec Regparam = 0.597717038888587

// %% [markdown]
// -  ## Variation du paramètre C pour SVM avec vectorisation Word2Vec Corpus 1

// %%
//LECTURE D'UN FICHIER AU FORMAT LIBSVM
val echantillon_LIBSVM: RDD[LabeledPoint] = MLUtils.loadLibSVMFile(sc, "Data/Vecto_Word2vec_V6")

//PARTAGE DE L'ECHANTILLON EN JEUX D'APPRENTISSAGE ET DE VALIDATION
val splits = echantillon_LIBSVM.randomSplit(Array(0.7, 0.3))
val (trainingData, validationData) = (splits(0), splits(1))

//APPLICATION DU MODELE AU JEU D'APPRENTISSAGE
val numIterations = 100
val modele_sansC = SVMWithSGD.train(trainingData, numIterations)

//EVALUATION DU MODELE AVEC VALEUR C PAR DEFAUT
modele_sansC.clearThreshold()
//APPLICATION DU MODELE AU JEU DE VALIDATION
val scoreAndLabels_sansC = validationData.map { point =>
  val score = modele_sansC.predict(point.features)
  (score, point.label)
}
// CALCUL DE L'AIRE ROC
val metrics_sansC = new BinaryClassificationMetrics(scoreAndLabels_sansC)
val auROC_sansC = metrics_sansC.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.0
val C1 = 0.0
val svmAlgC1 = new SVMWithSGD()
svmAlgC1.optimizer
  .setNumIterations(100)
  .setRegParam(C1)
  .setUpdater(new L1Updater)
val modele_avecC1 = svmAlgC1.run(trainingData)
modele_avecC1.clearThreshold()

val scoreAndLabels_avecC1 = validationData.map { point =>
  val score = modele_avecC1.predict(point.features)
  (score, point.label)
}
val metrics_avecC1 = new BinaryClassificationMetrics(scoreAndLabels_avecC1)
val auROC_avecC1 = metrics_avecC1.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.00001
val C2 = 0.00001
val svmAlgC2 = new SVMWithSGD()
svmAlgC2.optimizer
  .setNumIterations(100)
  .setRegParam(C2)
  .setUpdater(new L1Updater)
val modele_avecC2 = svmAlgC2.run(trainingData)

modele_avecC2.clearThreshold()
val scoreAndLabels_avecC2 = validationData.map { point =>
  val score = modele_avecC2.predict(point.features)
  (score, point.label)
}
val metrics_avecC2 = new BinaryClassificationMetrics(scoreAndLabels_avecC2)
val auROC_avecC2 = metrics_avecC2.areaUnderROC()
 
//EVALUATION DU MODELE AVEC VALEUR C = 0.0001
val C3 = 0.0001
val svmAlgC3 = new SVMWithSGD()
svmAlgC3.optimizer
  .setNumIterations(100)
  .setRegParam(C3)
  .setUpdater(new L1Updater)
val modele_avecC3 = svmAlgC3.run(trainingData)
modele_avecC3.clearThreshold()
val scoreAndLabels_avecC3 = validationData.map { point =>
  val score = modele_avecC3.predict(point.features)
  (score, point.label)
}
val metrics_avecC3 = new BinaryClassificationMetrics(scoreAndLabels_avecC3)
val auROC_avecC3 = metrics_avecC3.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.0001
val C4 = 0.001
val svmAlgC4 = new SVMWithSGD()
svmAlgC4.optimizer
  .setNumIterations(100)
  .setRegParam(C4)
  .setUpdater(new L1Updater)
val modele_avecC4 = svmAlgC4.run(trainingData)

modele_avecC4.clearThreshold()
val scoreAndLabels_avecC4 = validationData.map { point =>
  val score = modele_avecC4.predict(point.features)
  (score, point.label)
}
val metrics_avecC4 = new BinaryClassificationMetrics(scoreAndLabels_avecC4)
val auROC_avecC4 = metrics_avecC4.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.01
val C5 = 0.01
val svmAlgC5 = new SVMWithSGD()
svmAlgC5.optimizer
  .setNumIterations(100)
  .setRegParam(C5)
  .setUpdater(new L1Updater)
val modele_avecC5 = svmAlgC5.run(trainingData)

modele_avecC5.clearThreshold()
val scoreAndLabels_avecC5 = validationData.map { point =>
  val score = modele_avecC5.predict(point.features)
  (score, point.label)
}
val metrics_avecC5 = new BinaryClassificationMetrics(scoreAndLabels_avecC5)
val auROC_avecC5 = metrics_avecC5.areaUnderROC()
println(s"paramètre de régularisation : C = $C5")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC5")

//EVALUATION DU MODELE AVEC VALEUR C = 0.01
val C6 = 0.1
val svmAlgC6 = new SVMWithSGD()
svmAlgC6.optimizer
  .setNumIterations(100)
  .setRegParam(C6)
  .setUpdater(new L1Updater)
val modele_avecC6 = svmAlgC6.run(trainingData)

modele_avecC6.clearThreshold()
val scoreAndLabels_avecC6 = validationData.map { point =>
  val score = modele_avecC6.predict(point.features)
  (score, point.label)
}
val metrics_avecC6 = new BinaryClassificationMetrics(scoreAndLabels_avecC6)
val auROC_avecC6 = metrics_avecC6.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.5
val C7 = 0.5
val svmAlgC7 = new SVMWithSGD()
svmAlgC7.optimizer
  .setNumIterations(100)
  .setRegParam(C7)
  .setUpdater(new L1Updater)
val modele_avecC7 = svmAlgC7.run(trainingData)

modele_avecC7.clearThreshold()
val scoreAndLabels_avecC7 = validationData.map { point =>
  val score = modele_avecC7.predict(point.features)
  (score, point.label)
}
val metrics_avecC7 = new BinaryClassificationMetrics(scoreAndLabels_avecC7)
val auROC_avecC7 = metrics_avecC7.areaUnderROC()
// Out:
// [Stage 7940:============================>                           (1 + 1) / 2]paramètre de régularisation : C = 0.01
// Area under ROC pour methode avec Regparam = 0.7793944823812424
// echantillon_LIBSVM = MapPartitionsRDD[15226] at map at MLUtils.scala:84
// splits = Array(MapPartitionsRDD[15227] at randomSplit at <console>:100, MapPartitionsRDD[15228] at randomSplit at <console>:100)
// trainingData = MapPartitionsRDD[15227] at randomSplit at <console>:100
// validationData = MapPartitionsRDD[15228] at randomSplit at <console>:100
// numIterations = 100
// modele_sansC = org.apache.spark.mllib.classification.SVMModel: intercept = 0...
// org.apache.spark.mllib.classification.SVMModel: intercept = 0.0, numFeatures = 100, numClasses = 2, threshold = None

// %%
println("Vectorisation avec Word2Vec Corpus1")
println("==========================================================")
println(s"Area under ROC pour methode sans Regparam = $auROC_sansC")
println(s"paramètre de régularisation : C = $C1")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC1")
println(s"paramètre de régularisation : C = $C2")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC2")
println(s"paramètre de régularisation : C = $C3")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC3")
println(s"paramètre de régularisation : C = $C4")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC4")
println(s"paramètre de régularisation : C = $C5")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC5")
println(s"paramètre de régularisation : C = $C6")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC6")
println(s"paramètre de régularisation : C = $C7")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC7")
// Out:
// Vectorisation avec Word2Vec Corpus1
// ==========================================================
// Area under ROC pour methode sans Regparam = 0.8335733818344719
// paramètre de régularisation : C = 0.0
// Area under ROC pour methode avec Regparam = 0.8407755456732431
// paramètre de régularisation : C = 1.0E-5
// Area under ROC pour methode avec Regparam = 0.8407479022926987
// paramètre de régularisation : C = 1.0E-4
// Area under ROC pour methode avec Regparam = 0.8404126377030187
// paramètre de régularisation : C = 0.001
// Area under ROC pour methode avec Regparam = 0.8359379540779663
// paramètre de régularisation : C = 0.01
// Area under ROC pour methode avec Regparam = 0.7793944823812424
// paramètre de régularisation : C = 0.1
// Area under ROC pour methode avec Regparam = 0.7591588190180792
// paramètre de régularisation : C = 0.5
// Area under ROC pour methode avec Regparam = 0.5

// %% [markdown]
// -  ## Variation du paramètre C pour SVM avec vectorisation Word2Vec Corpus 2

// %%
//LECTURE D'UN FICHIER AU FORMAT LIBSVM
val echantillon_LIBSVM: RDD[LabeledPoint] = MLUtils.loadLibSVMFile(sc, "Data/Vecto_Word2vecC2_V6")

//PARTAGE DE L'ECHANTILLON EN JEUX D'APPRENTISSAGE ET DE VALIDATION
val splits = echantillon_LIBSVM.randomSplit(Array(0.7, 0.3))
val (trainingData, validationData) = (splits(0), splits(1))

//APPLICATION DU MODELE AU JEU D'APPRENTISSAGE
val numIterations = 100
val modele_sansC = SVMWithSGD.train(trainingData, numIterations)

//EVALUATION DU MODELE AVEC C PAR DEFAUT
modele_sansC.clearThreshold()
//APPLICATION DU MODELE AU JEU DE VALIDATION
val scoreAndLabels_sansC = validationData.map { point =>
  val score = modele_sansC.predict(point.features)
  (score, point.label)
}
// CALCUL DE L'AIRE ROC
val metrics_sansC = new BinaryClassificationMetrics(scoreAndLabels_sansC)
val auROC_sansC = metrics_sansC.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.0
val C1 = 0.0
val svmAlgC1 = new SVMWithSGD()
svmAlgC1.optimizer
  .setNumIterations(100)
  .setRegParam(C1)
  .setUpdater(new L1Updater)
val modele_avecC1 = svmAlgC1.run(trainingData)

modele_avecC1.clearThreshold()
val scoreAndLabels_avecC1 = validationData.map { point =>
  val score = modele_avecC1.predict(point.features)
  (score, point.label)
}
val metrics_avecC1 = new BinaryClassificationMetrics(scoreAndLabels_avecC1)
val auROC_avecC1 = metrics_avecC1.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.00001
val C2 = 0.00001
val svmAlgC2 = new SVMWithSGD()
svmAlgC2.optimizer
  .setNumIterations(100)
  .setRegParam(C2)
  .setUpdater(new L1Updater)
val modele_avecC2 = svmAlgC2.run(trainingData)

modele_avecC2.clearThreshold()
val scoreAndLabels_avecC2 = validationData.map { point =>
  val score = modele_avecC2.predict(point.features)
  (score, point.label)
}
val metrics_avecC2 = new BinaryClassificationMetrics(scoreAndLabels_avecC2)
val auROC_avecC2 = metrics_avecC2.areaUnderROC()
 
//EVALUATION DU MODELE AVEC VALEUR C = 0.0001
val C3 = 0.0001
val svmAlgC3 = new SVMWithSGD()
svmAlgC3.optimizer
  .setNumIterations(100)
  .setRegParam(C3)
  .setUpdater(new L1Updater)
val modele_avecC3 = svmAlgC3.run(trainingData)

modele_avecC3.clearThreshold()
val scoreAndLabels_avecC3 = validationData.map { point =>
  val score = modele_avecC3.predict(point.features)
  (score, point.label)
}
val metrics_avecC3 = new BinaryClassificationMetrics(scoreAndLabels_avecC3)
val auROC_avecC3 = metrics_avecC3.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.001
val C4 = 0.001
val svmAlgC4 = new SVMWithSGD()
svmAlgC4.optimizer
  .setNumIterations(100)
  .setRegParam(C4)
  .setUpdater(new L1Updater)
val modele_avecC4 = svmAlgC4.run(trainingData)

modele_avecC4.clearThreshold()
val scoreAndLabels_avecC4 = validationData.map { point =>
  val score = modele_avecC4.predict(point.features)
  (score, point.label)
}
val metrics_avecC4 = new BinaryClassificationMetrics(scoreAndLabels_avecC4)
val auROC_avecC4 = metrics_avecC4.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.01
val C5 = 0.01
val svmAlgC5 = new SVMWithSGD()
svmAlgC5.optimizer
  .setNumIterations(100)
  .setRegParam(C5)
  .setUpdater(new L1Updater)
val modele_avecC5 = svmAlgC5.run(trainingData)

modele_avecC5.clearThreshold()
val scoreAndLabels_avecC5 = validationData.map { point =>
  val score = modele_avecC5.predict(point.features)
  (score, point.label)
}
val metrics_avecC5 = new BinaryClassificationMetrics(scoreAndLabels_avecC5)
val auROC_avecC5 = metrics_avecC5.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.1
val C6 = 0.1
val svmAlgC6 = new SVMWithSGD()
svmAlgC6.optimizer
  .setNumIterations(100)
  .setRegParam(C6)
  .setUpdater(new L1Updater)
val modele_avecC6 = svmAlgC6.run(trainingData)

modele_avecC6.clearThreshold()
val scoreAndLabels_avecC6 = validationData.map { point =>
  val score = modele_avecC6.predict(point.features)
  (score, point.label)
}
val metrics_avecC6 = new BinaryClassificationMetrics(scoreAndLabels_avecC6)
val auROC_avecC6 = metrics_avecC6.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.5
val C7 = 0.5
val svmAlgC7 = new SVMWithSGD()
svmAlgC7.optimizer
  .setNumIterations(100)
  .setRegParam(C7)
  .setUpdater(new L1Updater)
val modele_avecC7 = svmAlgC7.run(trainingData)

modele_avecC7.clearThreshold()
val scoreAndLabels_avecC7 = validationData.map { point =>
  val score = modele_avecC7.predict(point.features)
  (score, point.label)
}
val metrics_avecC7 = new BinaryClassificationMetrics(scoreAndLabels_avecC7)
val auROC_avecC7 = metrics_avecC7.areaUnderROC()
// Out:
// echantillon_LIBSVM = MapPartitionsRDD[16783] at map at MLUtils.scala:84
// splits = Array(MapPartitionsRDD[16784] at randomSplit at <console>:99, MapPartitionsRDD[16785] at randomSplit at <console>:99)
// trainingData = MapPartitionsRDD[16784] at randomSplit at <console>:99
// validationData = MapPartitionsRDD[16785] at randomSplit at <console>:99
// numIterations = 100
// modele_sansC = org.apache.spark.mllib.classification.SVMModel: intercept = 0.0, ...
// org.apache.spark.mllib.classification.SVMModel: intercept = 0.0, numFeatures = 100, numClasses = 2, threshold = None

// %%
println("Vectorisation avec Word2Vec Corpus2")
println("==========================================================")
println(s"Area under ROC pour methode sans Regparam = $auROC_sansC")
println(s"paramètre de régularisation : C = $C1")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC1")
println(s"paramètre de régularisation : C = $C2")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC2")
println(s"paramètre de régularisation : C = $C3")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC3")
println(s"paramètre de régularisation : C = $C4")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC4")
println(s"paramètre de régularisation : C = $C5")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC5")
println(s"paramètre de régularisation : C = $C6")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC6")
println(s"paramètre de régularisation : C = $C7")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC7")
// Out:
// Vectorisation avec Word2Vec Corpus2
// ==========================================================
// Area under ROC pour methode sans Regparam = 0.9636887469399716
// paramètre de régularisation : C = 0.0
// Area under ROC pour methode avec Regparam = 0.9641526371821877
// paramètre de régularisation : C = 1.0E-5
// Area under ROC pour methode avec Regparam = 0.9641503816380601
// paramètre de régularisation : C = 1.0E-4
// Area under ROC pour methode avec Regparam = 0.964100759667256
// paramètre de régularisation : C = 0.001
// Area under ROC pour methode avec Regparam = 0.9636609285623997
// paramètre de régularisation : C = 0.01
// Area under ROC pour methode avec Regparam = 0.9551454976331776
// paramètre de régularisation : C = 0.1
// Area under ROC pour methode avec Regparam = 0.8406473110906598
// paramètre de régularisation : C = 0.5
// Area under ROC pour methode avec Regparam = 0.5

// %% [markdown]
// -  ## Variation du paramètre C pour SVM avec vectorisation CountVectorizer

// %%
//LECTURE D'UN FICHIER AU FORMAT LIBSVM
val echantillon_LIBSVM: RDD[LabeledPoint] = MLUtils.loadLibSVMFile(sc, "Data/Vecto_Countvectorizer_V6")

//PARTAGE DE L'ECHANTILLON EN JEUX D'APPRENTISSAGE ET DE VALIDATION
val splits = echantillon_LIBSVM.randomSplit(Array(0.7, 0.3))
val (trainingData, validationData) = (splits(0), splits(1))

//APPLICATION DU MODELE AU JEU D'APPRENTISSAGE
val numIterations = 100
val modele_sansC = SVMWithSGD.train(trainingData, numIterations)

//EVALUATION DU MODELE AEC VALEUR C PAR DEFAUT
modele_sansC.clearThreshold()
//APPLICATION DU MODELE AU JEU DE VALIDATION
val scoreAndLabels_sansC = validationData.map { point =>
  val score = modele_sansC.predict(point.features)
  (score, point.label)
}
// CALCUL DE L'AIRE ROC
val metrics_sansC = new BinaryClassificationMetrics(scoreAndLabels_sansC)
val auROC_sansC = metrics_sansC.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.0
val C1 = 0.0
val svmAlgC1 = new SVMWithSGD()
svmAlgC1.optimizer
  .setNumIterations(100)
  .setRegParam(C1)
  .setUpdater(new L1Updater)
val modele_avecC1 = svmAlgC1.run(trainingData)

modele_avecC1.clearThreshold()
val scoreAndLabels_avecC1 = validationData.map { point =>
  val score = modele_avecC1.predict(point.features)
  (score, point.label)
}
val metrics_avecC1 = new BinaryClassificationMetrics(scoreAndLabels_avecC1)
val auROC_avecC1 = metrics_avecC1.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.00001
val C2 = 0.00001
val svmAlgC2 = new SVMWithSGD()
svmAlgC2.optimizer
  .setNumIterations(100)
  .setRegParam(C2)
  .setUpdater(new L1Updater)
val modele_avecC2 = svmAlgC2.run(trainingData)

modele_avecC2.clearThreshold()
val scoreAndLabels_avecC2 = validationData.map { point =>
  val score = modele_avecC2.predict(point.features)
  (score, point.label)
}
val metrics_avecC2 = new BinaryClassificationMetrics(scoreAndLabels_avecC2)
val auROC_avecC2 = metrics_avecC2.areaUnderROC()
 
//EVALUATION DU MODELE AVEC VALEUR C = 0.0001
val C3 = 0.0001
val svmAlgC3 = new SVMWithSGD()
svmAlgC3.optimizer
  .setNumIterations(100)
  .setRegParam(C3)
  .setUpdater(new L1Updater)
val modele_avecC3 = svmAlgC3.run(trainingData)

modele_avecC3.clearThreshold()
val scoreAndLabels_avecC3 = validationData.map { point =>
  val score = modele_avecC3.predict(point.features)
  (score, point.label)
}
val metrics_avecC3 = new BinaryClassificationMetrics(scoreAndLabels_avecC3)
val auROC_avecC3 = metrics_avecC3.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.001
val C4 = 0.001
val svmAlgC4 = new SVMWithSGD()
svmAlgC4.optimizer
  .setNumIterations(100)
  .setRegParam(C4)
  .setUpdater(new L1Updater)
val modele_avecC4 = svmAlgC4.run(trainingData)

modele_avecC4.clearThreshold()
val scoreAndLabels_avecC4 = validationData.map { point =>
  val score = modele_avecC4.predict(point.features)
  (score, point.label)
}
val metrics_avecC4 = new BinaryClassificationMetrics(scoreAndLabels_avecC4)
val auROC_avecC4 = metrics_avecC4.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.01
val C5 = 0.01
val svmAlgC5 = new SVMWithSGD()
svmAlgC5.optimizer
  .setNumIterations(100)
  .setRegParam(C5)
  .setUpdater(new L1Updater)
val modele_avecC5 = svmAlgC5.run(trainingData)

modele_avecC5.clearThreshold()
val scoreAndLabels_avecC5 = validationData.map { point =>
  val score = modele_avecC5.predict(point.features)
  (score, point.label)
}
val metrics_avecC5 = new BinaryClassificationMetrics(scoreAndLabels_avecC5)
val auROC_avecC5 = metrics_avecC5.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.1
val C6 = 0.1
val svmAlgC6 = new SVMWithSGD()
svmAlgC6.optimizer
  .setNumIterations(100)
  .setRegParam(C6)
  .setUpdater(new L1Updater)
val modele_avecC6 = svmAlgC6.run(trainingData)

modele_avecC6.clearThreshold()
val scoreAndLabels_avecC6 = validationData.map { point =>
  val score = modele_avecC6.predict(point.features)
  (score, point.label)
}
val metrics_avecC6 = new BinaryClassificationMetrics(scoreAndLabels_avecC6)
val auROC_avecC6 = metrics_avecC6.areaUnderROC()

//EVALUATION DU MODELE AVEC VALEUR C = 0.5
val C7 = 0.5
val svmAlgC7 = new SVMWithSGD()
svmAlgC7.optimizer
  .setNumIterations(100)
  .setRegParam(C7)
  .setUpdater(new L1Updater)
val modele_avecC7 = svmAlgC7.run(trainingData)

modele_avecC7.clearThreshold()
val scoreAndLabels_avecC7 = validationData.map { point =>
  val score = modele_avecC7.predict(point.features)
  (score, point.label)
}
val metrics_avecC7 = new BinaryClassificationMetrics(scoreAndLabels_avecC7)
val auROC_avecC7 = metrics_avecC7.areaUnderROC()
// Out:
// echantillon_LIBSVM = MapPartitionsRDD[18340] at map at MLUtils.scala:84
// splits = Array(MapPartitionsRDD[18341] at randomSplit at <console>:99, MapPartitionsRDD[18342] at randomSplit at <console>:99)
// trainingData = MapPartitionsRDD[18341] at randomSplit at <console>:99
// validationData = MapPartitionsRDD[18342] at randomSplit at <console>:99
// numIterations = 100
// modele_sansC = org.apache.spark.mllib.classification.SVMModel: intercept = 0.0, ...
// org.apache.spark.mllib.classification.SVMModel: intercept = 0.0, numFeatures = 3444, numClasses = 2, threshold = None

// %%
println("Vectorisation avec CountVectorizer")
println("==========================================================")
println(s"Area under ROC pour methode sans Regparam = $auROC_sansC")
println(s"paramètre de régularisation : C = $C1")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC1")
println(s"paramètre de régularisation : C = $C2")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC2")
println(s"paramètre de régularisation : C = $C3")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC3")
println(s"paramètre de régularisation : C = $C4")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC4")
println(s"paramètre de régularisation : C = $C5")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC5")
println(s"paramètre de régularisation : C = $C6")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC6")
println(s"paramètre de régularisation : C = $C7")
println(s"Area under ROC pour methode avec Regparam = $auROC_avecC7")
// Out:
// Vectorisation avec CountVectorizer
// ==========================================================
// Area under ROC pour methode sans Regparam = 0.9697640497770469
// paramètre de régularisation : C = 0.0
// Area under ROC pour methode avec Regparam = 0.9711234368941458
// paramètre de régularisation : C = 1.0E-5
// Area under ROC pour methode avec Regparam = 0.9710545208898806
// paramètre de régularisation : C = 1.0E-4
// Area under ROC pour methode avec Regparam = 0.9707228152869342
// paramètre de régularisation : C = 0.001
// Area under ROC pour methode avec Regparam = 0.967283073623498
// paramètre de régularisation : C = 0.01
// Area under ROC pour methode avec Regparam = 0.928549628610898
// paramètre de régularisation : C = 0.1
// Area under ROC pour methode avec Regparam = 0.648341699180884
// paramètre de régularisation : C = 0.5
// Area under ROC pour methode avec Regparam = 0.5982681635323769
