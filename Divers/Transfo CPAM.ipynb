# %%
import pandas, numpy, pyensae, os
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

path ="/home/user/PROJETS/DATA/Assurance Maladie"
os.chdir(path)

mydata = pandas.read_csv("R201601.CSV", sep=";", header = 0, decimal= ",", thousands=".", encoding='iso-8859-1')
mydata.head()
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    cpam           l_cpam dpt                 l_dpt  region  \
# 0   171  171-La Rochelle  17  17-Charente-maritime      54
# 1   371        371-Tours  37     37-Indre-et-Loire      24
# 2   595        595-Lille  59                5-Nord      31
# 3   597      597-Roubaix  59                5-Nord      31
# 4   624         624-Lens  62      62-Pas-de-Calais      31
#
#                 l_region           l_serie   SERIE  prs_nat  \
# 0    54-POITOU CHARENTES  C Omnipraticiens  111111     1111
# 1              24-CENTRE  C Omnipraticiens  111111     1111
# 2  31-NORD PAS DE CALAIS  C Omnipraticiens  111111     1111
# 3  31-NORD PAS DE CALAIS  C Omnipraticiens  111111     1111
# ...

# %%
#columns = ['SERIE']
columns =['cpam', 'l_cpam', 'dpt',  'region',  'l_serie',
       'prs_nat',   'asu_nat', 'cpl_cod',
        'ben_qlt', 'pre_spe', 
       'pre_spe1',  'pre_stj1',  'exe_spe',
        'exe_spe1',  'exe_stj1']
mydata.drop(columns, inplace=True, axis=1)

mydata.head()
# Out:
#                   l_dpt               l_region             l_prs_nat  \
# 0  17-Charente-maritime    54-POITOU CHARENTES  CONSULTATION COTEE C
# 1     37-Indre-et-Loire              24-CENTRE  CONSULTATION COTEE C
# 2                5-Nord  31-NORD PAS DE CALAIS  CONSULTATION COTEE C
# 3                5-Nord  31-NORD PAS DE CALAIS  CONSULTATION COTEE C
# 4      62-Pas-de-Calais  31-NORD PAS DE CALAIS  CONSULTATION COTEE C
#
#    sns_date l_asu_nat        l_cpl_cod l_ben_qlt  REM_TAU  \
# 0    201201   Maladie  Sans majoration  1-Assuré       30
# 1    201201   Maladie  Sans majoration  1-Assuré       30
# 2    201201   Maladie  Sans majoration  1-Assuré       30
# 3    201201   Maladie  Sans majoration  1-Assuré       30
# 4    201201   Maladie  Sans majoration  1-Assuré       30
#
#                  l_pre_spe                        l_pre_spe1   ...     \
# 0  01-TOTAL Omnipraticiens  Médecins Omnipraticiens libéraux   ...
# ...

# %%
mydata.dtypes
mydata.to_csv("DD_R201601.csv")
